# %% [markdown]
# Last Session Review
# - both request methods: .get (retrieving data from apis, staying in the browser history but not secure) vs. .post (posting to the backend of apis, longer and secure messages, such as when setting passwords or posting articles)

# %% [markdown]
# I/O Programming
# - Excel files when changing extention to .zip will be in the format of folders and can be opened by VS code
# - Data is in the worksheets folder
